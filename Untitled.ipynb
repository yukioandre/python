# %%
import os
os.getcwd()
os.chdir("/Users/andremota/DataScience/Fifa19")

# %%
#https://www.kaggle.com/ekami66/detailed-exploratory-data-analysis-with-python

import pandas as pd

df = pd.read_csv('fifa19.csv', header=0, index_col=0)
df.head(1)
# Out:
#        ID      Name  Age                                           Photo  \
# 0  158023  L. Messi   31  https://cdn.sofifa.org/players/4/19/158023.png
#
#   Nationality                                 Flag  Overall  Potential  \
# 0   Argentina  https://cdn.sofifa.org/flags/52.png       94         94
#
#            Club                                     Club Logo      ...        \
# 0  FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png      ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
#
# [1 rows x 88 columns]

# %%
# CONVERTE COLUNA PESO PARA NUMERO (PRECISA EXCLUIR O LBS DA CELULA)

# Ve qual tipo da variavel da coluna
df['Weight'].dtypes

# Agora que sei que é tipo O (objeto), converto para string
df['Weight'] = df['Weight'].astype('str') 

# Vai continuar aparecendo como objeto, mas agora o proximo codigo funciona

# Cria uma coluna nova para peso
import re
df['Weight'].head()

# Apaga 'lbs' da coluna peso
df['Weight_New'] = df['Weight'].map(lambda x: re.sub(r'lbs', '', x))

df['Weight_New'].dtypes

# Coloca 99999 para quem tem nan (depois ver o que fazer)
df['Weight_New'] = df['Weight_New'].map(lambda x: re.sub(r'nan', '99999', x))

# Converte Weight_New de string pra numeric
df['Weight_New']=pd.to_numeric(df.Weight_New)
df['Weight_New'].dtypes
# Out:
# dtype('int64')

# %%
# Criar uma função no Python pra receber valor com base nos valores de outra coluna
#def label_race (row):
#    if row['Nationality'] == 'Brazil':
#        return 1
#    else:
#        return 0
    
#df.apply (lambda row: label_race(row), axis=1)

#df['fl_brasil'] = df.apply (lambda row: label_race(row), axis=1)
#df.head()

# %%
# CRIA UMA COLUNA CHAMADA VALOR_FINAL(K) COM OS VALORES DA RELEASE CLAUSE EM MILHARES

# Codigo para filtrar e conferir se é K minúsculo ou maiúsculo (verifico se contem k minusculo ou maiusculo)
df[df['Release Clause'].str.contains("K",na = False)]

# Converte o campo Release Clause para string (sim, precisa fazer isso)
df['Release Clause'] = df['Release Clause'].astype('str') 

# Se for valor em M, coluna milhoes recebe o valor e a coluna mil nao
df.loc[df['Release Clause'].str.contains('M'), 'Valor_M'] = df['Release Clause'].map(lambda x: re.sub(r'M', '', x))
df.loc[~df['Release Clause'].str.contains('M'), 'Valor_M'] = 0

# Agora faz o contrario e cria coluna Valor_K
df.loc[df['Release Clause'].str.contains('K'), 'Valor_K'] = df['Release Clause'].map(lambda x: re.sub(r'K', '', x))
df.loc[~df['Release Clause'].str.contains('K'), 'Valor_K'] = 0

# Converte os campos criados para string (sim, precisa fazer isso)
df['Valor_M'] = df['Valor_M'].astype('str') 
df['Valor_K'] = df['Valor_K'].astype('str') 

# Agora, tira o símbolo da moeda das colunas
df['Valor_M'] = df['Valor_M'].map(lambda x: re.sub(r'€', '', x))
df['Valor_K'] = df['Valor_K'].map(lambda x: re.sub(r'€', '', x))

# Converte as duas colunas para numero
df['Valor_M']=pd.to_numeric(df.Valor_M)
df['Valor_K']=pd.to_numeric(df.Valor_K)

# Agora, se coluna M não for nula, traz valor dela * 1000
# se a coluna M for nula, traz coluna K
df['Valor_Final(K)'] = df['Valor_M']*1000 + df['Valor_K']
df['Valor_Final(K)'].dtypes

#df['Valor_Final'] = df['Valor_K']+df['Valor_M']
df.tail()
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                    Club                                       Club Logo  \
# 18202   Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203    Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204  Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#            ...       GKDiving GKHandling  GKKicking GKPositioning  GKReflexes  \
# 18202      ...           10.0       13.0        7.0           8.0         9.0
# 18203      ...           10.0        9.0        9.0           5.0        12.0
# 18204      ...            6.0        5.0       10.0           6.0        13.0
# 18205      ...           14.0        6.0       14.0           8.0         9.0
# 18206      ...           10.0       15.0        9.0          12.0         9.0
#
#        Release Clause  Weight_New Valor_M Valor_K Valor_Final(K)
# 18202           €143K         134     0.0     143          143.0
# 18203           €113K         170     0.0     113          113.0
# 18204           €165K         148     0.0     165          165.0
# 18205           €143K         154     0.0     143          143.0
# 18206           €165K         176     0.0     165          165.0
#
# [5 rows x 92 columns]

# %%
df.isnull().sum()
df['ShortPassing'].fillna(df['ShortPassing'].mean(), inplace = True)
df['Volleys'].fillna(df['Volleys'].mean(), inplace = True)
df['Dribbling'].fillna(df['Dribbling'].mean(), inplace = True)
df['Curve'].fillna(df['Curve'].mean(), inplace = True)
df['FKAccuracy'].fillna(df['FKAccuracy'], inplace = True)
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                          0
# LS                           2085
# ST                           2085
# RS                           2085
# LW                           2085
# LF                           2085
# CF                           2085
# RF                           2085
# RW                           2085
# LAM                          2085
# CAM                          2085
# RAM                          2085
# LM                           2085
# LCM                          2085
# CM                           2085
# RCM                          2085
# RM                           2085
# LWB                          2085
# LDM                          2085
# CDM                          2085
# RDM                          2085
# RWB                          2085
# LB                           2085
# LCB                          2085
# CB                           2085
# RCB                          2085
# RB                           2085
# Crossing                       48
# Finishing                      48
# HeadingAccuracy                48
# ShortPassing                   48
# Volleys                        48
# Dribbling                      48
# Curve                          48
# FKAccuracy                     48
# LongPassing                    48
# BallControl                    48
# Acceleration                   48
# SprintSpeed                    48
# Agility                        48
# Reactions                      48
# Balance                        48
# ShotPower                      48
# Jumping                        48
# Stamina                        48
# Strength                       48
# LongShots                      48
# Aggression                     48
# Interceptions                  48
# Positioning                    48
# Vision                         48
# Penalties                      48
# Composure                      48
# Marking                        48
# StandingTackle                 48
# SlidingTackle                  48
# GKDiving                       48
# GKHandling                     48
# GKKicking                      48
# GKPositioning                  48
# GKReflexes                     48
# Release Clause                  0
# Weight_New                      0
# Valor_M                         0
# Valor_K                         0
# Valor_Final(K)                  0
# dtype: int64

# %%
#import numpy as np
# Seleciona somente as colunas numéricas
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_numeric = df.select_dtypes(include=numerics)
df_numeric = df_numeric.drop(['ID'], axis=1)
list(df_numeric.columns.values)
# Out:
# ['Age',
#  'Overall',
#  'Potential',
#  'Special',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Jersey Number',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes',
#  'Weight_New',
#  'Valor_M',
#  'Valor_K',
#  'Valor_Final(K)']

# %% [markdown]
# ## ANÁLISE JOGADORES

# %%
# O que se correlaciona mais com o valor dos jogadores
# Verifica correlacao de valor final com as demais
corr = df_numeric[list(df_numeric.columns.values)].corrwith(df_numeric['Valor_Final(K)'])

# Verifica quais variaveis tem correlacao modulo acima de 0.25 (maior que 0.25 ou menor que -0.25)
corr[abs(corr) > 0.25]

# ordena as correlacoes encontradas acima
corr[abs(corr) > 0.25].sort_values(kind="quicksort")
# Out:
# LongShots                   0.253442
# ShotPower                   0.255502
# Volleys                     0.258975
# Curve                       0.263058
# LongPassing                 0.283563
# BallControl                 0.284424
# Skill Moves                 0.289268
# ShortPassing                0.305538
# Vision                      0.331892
# Special                     0.351100
# Composure                   0.420584
# Reactions                   0.509542
# Potential                   0.547668
# Overall                     0.589200
# International Reputation    0.618094
# Valor_M                     0.999643
# Valor_Final(K)              1.000000
# dtype: float64

# %%
# Correlação entre Overall e o resto das variaveis
corr = df_numeric[list(df_numeric.columns.values)].corrwith(df_numeric['Overall'])

# Verifica quais variaveis tem correl maior que 0.25 ou menor que -0.25
corr[abs(corr) > 0.25]

# ordena as correlacoes encontradas acima
corr[abs(corr) > 0.25].sort_values(kind="quicksort")
# Out:
# Valor_K                    -0.397542
# StandingTackle              0.252629
# Jumping                     0.264435
# Agility                     0.264952
# Marking                     0.286505
# Interceptions               0.321326
# Finishing                   0.332515
# HeadingAccuracy             0.340776
# Penalties                   0.341429
# Strength                    0.349326
# Positioning                 0.356493
# Stamina                     0.365656
# Dribbling                   0.372426
# Volleys                     0.391338
# Crossing                    0.394972
# Aggression                  0.395470
# FKAccuracy                  0.396892
# Skill Moves                 0.414463
# Curve                       0.419491
# LongShots                   0.420795
# ShotPower                   0.441118
# Age                         0.452350
# BallControl                 0.460197
# LongPassing                 0.483909
# Vision                      0.498894
# International Reputation    0.499491
# ShortPassing                0.502550
# Valor_Final(K)              0.589200
# Valor_M                     0.596179
# Special                     0.606960
# Potential                   0.660939
# Composure                   0.727655
# Reactions                   0.850045
# Overall                     1.000000
# dtype: float64

# %%
# Correlação entre peso e as variaveis
corr = df_numeric[list(df_numeric.columns.values)].corrwith(df_numeric['Weight_New'])

# Verifica quais variaveis tem correlacao modulo acima de 0.25 (maior que 0.25 ou menor que -0.25)
corr[abs(corr) > 0.25]

# ordena as correlacoes encontradas acima
corr[abs(corr) > 0.25].sort_values(kind="quicksort")
# Out:
# Balance         -0.663905
# Agility         -0.534264
# Acceleration    -0.477853
# Dribbling       -0.414228
# SprintSpeed     -0.410936
# Crossing        -0.393323
# Skill Moves     -0.351209
# Positioning     -0.350330
# Curve           -0.345941
# BallControl     -0.337702
# FKAccuracy      -0.305175
# Finishing       -0.292407
# ShortPassing    -0.290366
# Vision          -0.284113
# LongShots       -0.278069
# Volleys         -0.262884
# LongPassing     -0.260863
# Penalties       -0.253387
# GKKicking        0.337717
# GKHandling       0.339024
# GKDiving         0.340034
# GKReflexes       0.341135
# GKPositioning    0.342178
# Strength         0.615798
# Weight_New       1.000000
# dtype: float64

# %%
# PARA CRIAR UMA MATRIZ DE CORREL

# Coloca limite para o numero de linhas que aparece
pd.options.display.max_rows = None

# Matriz de Correlacao 
corr = df_numeric.corr()
corr.shape

# Coloca NA na diagonal e no triang inferior
corr_triu = corr.where(~np.tril(np.ones(corr.shape)).astype(np.bool))
corr_triu

# Seleciona só correlações acima de 0.3
corr_triu = corr_triu.stack()
corr_triu[corr_triu > 0.3]

# Se quiser deixar melhor visualmente
corr_triu.name = 'Pearson Correlation Coefficient'
corr_triu[corr_triu > 0.3].to_frame()
# Out:
#                                                    Pearson Correlation Coefficient
# Age                      Overall                                          0.452350
#                          Reactions                                        0.453124
#                          Strength                                         0.332798
#                          Composure                                        0.391023
# Overall                  Potential                                        0.660939
#                          Special                                          0.606960
#                          International Reputation                         0.499491
#                          Skill Moves                                      0.414463
#                          Crossing                                         0.394972
#                          Finishing                                        0.332515
#                          HeadingAccuracy                                  0.340776
#                          ShortPassing                                     0.502550
#                          Volleys                                          0.391338
#                          Dribbling                                        0.372426
#                          Curve                                            0.419491
#                          FKAccuracy                                       0.396892
#                          LongPassing                                      0.483909
#                          BallControl                                      0.460197
#                          Reactions                                        0.850045
#                          ShotPower                                        0.441118
#                          Stamina                                          0.365656
#                          Strength                                         0.349326
#                          LongShots                                        0.420795
#                          Aggression                                       0.395470
#                          Interceptions                                    0.321326
#                          Positioning                                      0.356493
#                          Vision                                           0.498894
#                          Penalties                                        0.341429
#                          Composure                                        0.727655
#                          Valor_M                                          0.596179
#                          Valor_Final(K)                                   0.589200
# Potential                Special                                          0.383727
#                          International Reputation                         0.372993
#                          Skill Moves                                      0.354290
#                          ShortPassing                                     0.369189
#                          Dribbling                                        0.315019
#                          LongPassing                                      0.321437
#                          BallControl                                      0.354396
#                          Reactions                                        0.513425
#                          Vision                                           0.348141
#                          Composure                                        0.440008
#                          Valor_M                                          0.554902
#                          Valor_Final(K)                                   0.547668
# Special                  Weak Foot                                        0.341855
#                          Skill Moves                                      0.763412
#                          Crossing                                         0.866417
#                          Finishing                                        0.724244
#                          HeadingAccuracy                                  0.644421
#                          ShortPassing                                     0.906729
#                          Volleys                                          0.773974
#                          Dribbling                                        0.874274
#                          Curve                                            0.851900
#                          FKAccuracy                                       0.806414
#                          LongPassing                                      0.846302
#                          BallControl                                      0.912107
#                          Acceleration                                     0.654337
#                          SprintSpeed                                      0.645963
#                          Agility                                          0.699673
#                          Reactions                                        0.597169
#                          Balance                                          0.586788
#                          ShotPower                                        0.835277
#                          Jumping                                          0.321846
#                          Stamina                                          0.792762
#                          LongShots                                        0.840049
#                          Aggression                                       0.666236
#                          Interceptions                                    0.561676
#                          Positioning                                      0.824307
#                          Vision                                           0.761992
#                          Penalties                                        0.734533
#                          Composure                                        0.752331
#                          Marking                                          0.561866
#                          StandingTackle                                   0.538802
#                          SlidingTackle                                    0.506968
#                          Valor_M                                          0.355599
#                          Valor_Final(K)                                   0.351100
# International Reputation Reactions                                        0.445614
#                          Composure                                        0.392787
#                          Valor_M                                          0.618806
#                          Valor_Final(K)                                   0.618094
# Weak Foot                Skill Moves                                      0.340721
#                          Crossing                                         0.307925
#                          Finishing                                        0.357416
#                          ShortPassing                                     0.322133
#                          Volleys                                          0.357340
#                          Dribbling                                        0.352658
#                          Curve                                            0.345468
#                          FKAccuracy                                       0.330472
#                          BallControl                                      0.356383
#                          Agility                                          0.302062
#                          ShotPower                                        0.332855
#                          LongShots                                        0.355967
#                          Positioning                                      0.346896
#                          Vision                                           0.337897
#                          Penalties                                        0.330252
#                          Positioning                                      0.381700
#                          Vision                                           0.300083
#                          Penalties                                        0.336089
#                          Composure                                        0.515776
#                          Marking                                          0.723961
#                          StandingTackle                                   0.744216
#                          SlidingTackle                                    0.721384
# Interceptions            Composure                                        0.397450
#                          Marking                                          0.888349
#                          StandingTackle                                   0.941471
#                          SlidingTackle                                    0.928282
# Positioning              Vision                                           0.734367
#                          Penalties                                        0.801268
#                          Composure                                        0.580498
# Vision                   Penalties                                        0.632927
#                          Composure                                        0.636280
#                          Valor_M                                          0.336135
#                          Valor_Final(K)                                   0.331892
# Penalties                Composure                                        0.551801
# Composure                Marking                                          0.384081
#                          StandingTackle                                   0.351726
#                          SlidingTackle                                    0.317492
#                          Valor_M                                          0.425739
#                          Valor_Final(K)                                   0.420584
# Marking                  StandingTackle                                   0.906541
#                          SlidingTackle                                    0.895908
# StandingTackle           SlidingTackle                                    0.974659
# GKDiving                 GKHandling                                       0.970280
#                          GKKicking                                        0.965685
#                          GKPositioning                                    0.969864
#                          GKReflexes                                       0.973320
#                          Weight_New                                       0.340034
# GKHandling               GKKicking                                        0.965239
#                          GKPositioning                                    0.969408
#                          GKReflexes                                       0.970264
#                          Weight_New                                       0.339024
# GKKicking                GKPositioning                                    0.964336
#                          GKReflexes                                       0.966337
#                          Weight_New                                       0.337717
# GKPositioning            GKReflexes                                       0.970130
#                          Weight_New                                       0.342178
# GKReflexes               Weight_New                                       0.341135
# Valor_M                  Valor_Final(K)                                   0.999643

# %%
# Cria HeatMap
# %matplotlib notebook

import matplotlib.pyplot as plt

from pandas import DataFrame

import numpy as np

import seaborn as sns

plt.figure(figsize=(12,12))


# plota heatmap
ax = sns.heatmap(corr.T)

# turn the axis label
for item in ax.get_yticklabels():
    item.set_rotation(0)

for item in ax.get_xticklabels():
    item.set_rotation(90)

plt.savefig("heatmap.png")
# show figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# Verifica linearidade (Criar graficos)

# %%
# O que predict o Overall?
import numpy as np
from sklearn.linear_model import LinearRegression

# Exclui linhas que contenham NA
df_numeric = df_numeric.dropna(axis='rows')

# Separa variaveis independentes da dependente
x = df_numeric.loc[:, df_numeric.columns != 'Overall']
y = df_numeric.loc[:, df_numeric.columns == 'Overall']

# roda regressao
model = LinearRegression().fit(x, y)
print(model)

# Resultados
r_sq = model.score(x, y)

print('coefficient of determination:', r_sq)

print('intercept:', model.intercept_)

print('slope:', model.coef_)

# prediction with sklearn
# print ('Predicted Overall: \n', regr.predict([[listar variaveis aqui]]))


# COM OUTRA BIBLIOTECA:
# with statsmodels
#x= sm.add_constant(x) # adding a constant
 
#model = sm.OLS(y, x).fit()
#predictions = model.predict(x) 
 
#print_model = model.summary()
#print(print_model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# coefficient of determination: 0.9303149514605453
# intercept: [-20.94601418]
# slope: [[ 1.59146907e-05  5.55097385e-01  5.09327318e-01  5.47855347e-02
#    5.55387285e-01 -6.98310998e-04  8.39155456e-01 -1.05989883e-02
#   -4.07713839e-02 -4.02238557e-02 -5.95709096e-03 -1.47140721e-02
#   -5.64204298e-02 -5.81392917e-02 -5.23161341e-02 -5.31038083e-02
#   -5.47704305e-02  1.67239944e-02 -3.61875574e-02 -3.13690519e-02
#   -4.96984118e-02  9.04849244e-02 -6.86036870e-02 -4.08655282e-02
#   -5.08250565e-02 -2.48182301e-02 -3.21733030e-02 -6.01041761e-02
#   -5.44551258e-02 -5.27748510e-02 -7.78405012e-02 -7.28372912e-02
#   -6.66632123e-02  4.38295783e-02 -3.99105192e-02 -3.94937408e-02
#   -7.22330252e-02 -8.39670447e-03 -1.60245115e-02 -3.40768072e-02
#   -2.97452811e-02 -8.35434980e-04  1.07506809e-02]]

# %% [markdown]
# ## ANÁLISE PARA O TOP 10 CLUBES

# %%
# Clubes com mais fortes
df[df.groupby('Club')['Overall'].transform('size') > 1].groupby(['Club'])['Overall'].mean().nlargest(10)
# Out:
# Club
# Juventus               82.280000
# Napoli                 80.000000
# Inter                  79.750000
# Real Madrid            78.242424
# Milan                  78.074074
# FC Barcelona           78.030303
# Paris Saint-Germain    77.433333
# Roma                   77.423077
# Manchester United      77.242424
# FC Bayern München      77.000000
# Name: Overall, dtype: float64

# %%
# Número de jogadores por clube
df[df.groupby('Club')['Overall'].transform('size') > 1].groupby(['Club'])['Valor_Final(K)'].count().nlargest(10)
# Out:
# Club
# AS Monaco              33
# Arsenal                33
# Atlético Madrid        33
# Borussia Dortmund      33
# Burnley                33
# CD Leganés             33
# Cardiff City           33
# Chelsea                33
# Eintracht Frankfurt    33
# Empoli                 33
# Name: Valor_Final(K), dtype: int64

# %%
# Clubes mais caros
df[df.groupby('Club')['Overall'].transform('size') > 1].groupby(['Club'])['Valor_Final(K)'].sum().nlargest(10)
# Out:
# Club
# Real Madrid            1857688.0
# FC Barcelona           1813000.0
# Manchester City        1512907.0
# Atlético Madrid        1375649.0
# Paris Saint-Germain    1216266.0
# Juventus               1193600.0
# Tottenham Hotspur      1192323.0
# Liverpool              1155832.0
# Manchester United      1142500.0
# Chelsea                1092814.0
# Name: Valor_Final(K), dtype: float64

# %%
# Filtra clubes top 10
club = df[df.groupby('Club')['Overall'].transform('size') > 1].groupby(['Club'])['Overall'].mean().nlargest(10)
df_club = df.loc[df['Club'].isin(club.reset_index()['Club'])]

# Verifica se filtrou da forma correta
df_club.Club.unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Real Madrid', 'FC Bayern München', 'Napoli',
#        'Milan', 'Inter', 'Roma'], dtype=object)

# %%
# Compara as skills dos clubes

# Para que o Python não oculte nada, colocar None nas duas igualdades abaixo
pd.options.display.max_columns = 4
pd.options.display.max_rows = 10

# Analise descritiva de todas variaveis por clube
print(df_club.groupby('Club').describe(include='all'))
# Out:
#                     Acceleration        ...  Work Rate
#                            count unique ...        75%  max
# Club                                    ...
# FC Barcelona                33.0    NaN ...        NaN  NaN
# FC Bayern München           29.0    NaN ...        NaN  NaN
# Inter                       24.0    NaN ...        NaN  NaN
# Juventus                    25.0    NaN ...        NaN  NaN
# Manchester United           33.0    NaN ...        NaN  NaN
# Milan                       27.0    NaN ...        NaN  NaN
# Napoli                      25.0    NaN ...        NaN  NaN
# Paris Saint-Germain         30.0    NaN ...        NaN  NaN
# Real Madrid                 33.0    NaN ...        NaN  NaN
# Roma                        26.0    NaN ...        NaN  NaN
#
# [10 rows x 1001 columns]

# %%
# Faz com que 
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# Verifica a media de cada caracteristica por clube
df_club.groupby('Club').mean()


# Obtem o melhor em cada criterio
df_club.groupby('Club').mean().idxmax()
# Out:
# ID                                  Real Madrid
# Age                                       Inter
# Overall                                Juventus
# Potential                              Juventus
# Special                                Juventus
# International Reputation               Juventus
# Weak Foot                                Napoli
# Skill Moves                 Paris Saint-Germain
# Jersey Number                             Inter
# Crossing                    Paris Saint-Germain
# Finishing                     Manchester United
# HeadingAccuracy                        Juventus
# ShortPassing                       FC Barcelona
# Volleys                                Juventus
# Dribbling                              Juventus
# Curve                         Manchester United
# FKAccuracy                    Manchester United
# LongPassing                        FC Barcelona
# BallControl                 Paris Saint-Germain
# Acceleration                Paris Saint-Germain
# SprintSpeed                            Juventus
# Agility                     Paris Saint-Germain
# Reactions                              Juventus
# Balance                     Paris Saint-Germain
# ShotPower                              Juventus
# Jumping                                Juventus
# Stamina                                Juventus
# Strength                               Juventus
# LongShots                                Napoli
# Aggression                    Manchester United
# Interceptions                          Juventus
# Positioning                   Manchester United
# Vision                             FC Barcelona
# Penalties                     Manchester United
# Composure                              Juventus
# Marking                                Juventus
# StandingTackle                         Juventus
# SlidingTackle                          Juventus
# GKDiving                                  Inter
# GKHandling                                Milan
# GKKicking                     FC Bayern München
# GKPositioning                             Inter
# GKReflexes                                Inter
# Weight_New                             Juventus
# Valor_M                             Real Madrid
# Valor_K                       FC Bayern München
# Valor_Final(K)                      Real Madrid
# dtype: object

# %%
#print("Club with highest overall: "+ df_club.groupby('Club')['Overall'].mean()
#      .reset_index().sort_values('Overall',ascending=False).iloc[0,0])

# %%
# Analise visual

# %% [markdown]
# ## ANÁLISE PARA O TOP 10 PAÍSES

# %%
# Clubes com maior media Overall (incluindo soh quem tem mais de 250 jogadores)
df[df.groupby('Nationality')['Overall'].transform('size') > 250].groupby(['Nationality'])['Overall'].mean().nlargest(10)
# Out:
# Nationality
# Portugal       71.344720
# Brazil         71.251511
# Spain          69.698694
# Belgium        68.811538
# Argentina      68.572038
# Italy          68.158120
# France         67.798687
# Netherlands    67.653422
# Germany        66.086811
# Turkey         66.072607
# Name: Overall, dtype: float64

# %%
print("Quartile England")
print(df[df.Nationality=='England'].Overall.quantile([.1, .25, .5, .75, .99]))
print("")
print("Quartile Turkey")
print(df[df.Nationality=='Turkey'].Overall.quantile([.1, .25, .5, .75, .99]))
# Out:
# Quartile England
# 0.10    55.0
# 0.25    59.0
# 0.50    63.0
# 0.75    67.0
# 0.99    80.0
# Name: Overall, dtype: float64
#
# Quartile Turkey
# 0.10    57.0
# 0.25    61.0
# 0.50    67.0
# 0.75    71.0
# 0.99    79.0
# Name: Overall, dtype: float64

# %%
# Clubes com maior media Overall (incluindo soh quem tem mais de 250 jogadores)
df[df.groupby('Nationality')['Overall'].transform('size') > 250].groupby(['Nationality'])['Overall'].std().nlargest(25)
# Out:
# Nationality
# Denmark                7.483343
# France                 7.007972
# England                6.785315
# Poland                 6.771276
# Belgium                6.723372
# Republic of Ireland    6.667912
# Germany                6.638976
# Sweden                 6.607183
# Italy                  6.530675
# Scotland               6.521725
# Spain                  6.494103
# Turkey                 6.463449
# Colombia               6.348972
# Chile                  6.268557
# Argentina              6.166440
# Austria                6.141130
# Norway                 6.136230
# Mexico                 6.134350
# Netherlands            6.074862
# Japan                  6.023445
# China PR               5.784686
# Brazil                 5.590515
# Portugal               5.469467
# United States          5.358844
# Saudi Arabia           4.936961
# Name: Overall, dtype: float64

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

plt.figure()
plt.title("Histograma Inglaterra")
#hist(df[df.Nationality=='Englang'].Overall.values, bins=50, range=(0,200))
df[df.Nationality=='England'].Overall.hist(bins=20)
plt.savefig("histEngland.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

plt.figure()
#hist(df[df.Nationality=='Englang'].Overall.values, bins=50, range=(0,200))
plt.title("Histograma Turquia")
df[df.Nationality=='Turkey'].Overall.hist(bins=20)
plt.savefig("histTurkey.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Clubes com maior media Overall (incluindo soh quem tem mais de 250 jogadores)
df[df.groupby('Nationality')['Overall'].transform('size') > 250].groupby(['Nationality'])['Overall'].std().nlargest(30)
# Out:
# Nationality
# Denmark                7.483343
# France                 7.007972
# England                6.785315
# Poland                 6.771276
# Belgium                6.723372
# Republic of Ireland    6.667912
# Germany                6.638976
# Sweden                 6.607183
# Italy                  6.530675
# Scotland               6.521725
# Spain                  6.494103
# Turkey                 6.463449
# Colombia               6.348972
# Chile                  6.268557
# Argentina              6.166440
# Austria                6.141130
# Norway                 6.136230
# Mexico                 6.134350
# Netherlands            6.074862
# Japan                  6.023445
# China PR               5.784686
# Brazil                 5.590515
# Portugal               5.469467
# United States          5.358844
# Saudi Arabia           4.936961
# Korea Republic         4.649993
# Name: Overall, dtype: float64

# %%
# Paises com maior Overall (incluindo soh quem tem mais de 250 jogadores)
df[df.groupby('Nationality')['Overall'].transform('size') > 250].groupby(['Nationality'])['Overall'].mean().nlargest(10)

# Filtra as 5 nações com maior overall
array = ['Portugal','Brazil','Spain','Belgium','Argentina']
df_2 = df[df['Nationality'].isin(array)]

# Verifica se só tem as nacionalidades que queremos
df_2.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium'],
#       dtype=object)

# %%
# Pede para que o Python não oculte nenhuma coluna
pd.options.display.max_columns = None

# Analise descritiva do Overall dos jogadores de cada nação
print(df_2.groupby('Nationality').describe(include='all'))

#print(df_2.groupby('Nationality')['Overall'].describe())
    
# Para todas variaveis ficaria muita coisa, mas seria: df_2.groupby('Nationality').describe()

# Poderia fazer um a um do seguinte modo: 
#df[df['Nationality']=='Brazil'].describe()
# Out:
#             Acceleration                                                    \
#                    count unique top freq       mean        std   min   25%
# Nationality
# Argentina          936.0    NaN NaN  NaN  64.625000  15.241492  15.0  56.0
# Belgium            259.0    NaN NaN  NaN  64.474903  15.889466  18.0  55.5
# Brazil             825.0    NaN NaN  NaN  66.318788  14.915342  12.0  59.0
# Portugal           322.0    NaN NaN  NaN  67.096273  14.745401  20.0  61.0
# Spain             1071.0    NaN NaN  NaN  63.587302  14.139743  14.0  55.0
#
# Belgium      18.148239   9.0  60.00  66.0  71.0  94.0       259      4
# Brazil       16.111648   8.0  60.00  69.0  74.0  95.0       825      4
# Portugal     16.723542  10.0  63.25  69.0  75.0  94.0       322      4
# Spain        17.572947  10.0  59.00  67.0  73.0  95.0      1071      3
#
#                                                               CAM         \
#                 top freq mean  std  min  25%  50%  75%  max count unique
# Nationality
# Argentina    Normal  610  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     66
# Belgium      Normal  137  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     51
# Brazil       Normal  523  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     66
# Portugal     Normal  203  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     53
# Spain        Normal  626  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     69
#
#                                                              CB               \
#               top freq mean  std  min  25%  50%  75%  max count unique   top
# Nationality
# Argentina    68+2   39  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     64  67+2
# Belgium      64+2   15  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     57  63+2
# Brazil       69+2   47  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     71  68+2
# Portugal     68+2   17  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     61  69+2
# Spain        66+2   52  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     80  66+2
#
#                                                       CDM                    \
#             freq mean  std  min  25%  50%  75%  max count unique   top freq
# Nationality
# Argentina     40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     62  57+2   42
# Belgium       12  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     50  66+2   14
# Brazil        40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     70  68+2   37
# Portugal      17  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     56  65+2   22
# Spain         41  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     69  62+2   46
#
#                                                   CF                         \
#             mean  std  min  25%  50%  75%  max count unique   top freq mean
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     68  65+2   42  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     52  62+2   16  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     71  68+2   55  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     52  67+2   18  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     67  63+2   52  NaN
#
#                                              CM                              \
#              std  min  25%  50%  75%  max count unique   top freq mean  std
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN   839     60  64+2   47  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN   219     46  57+2   14  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN   757     62  61+2   47  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN   290     45  61+2   21  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN   955     66  59+2   51  NaN  NaN
#
#                                       Club                                  \
#              min  25%  50%  75%  max count unique                      top
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN   936    182   San Lorenzo de Almagro
# Belgium      NaN  NaN  NaN  NaN  NaN   260     94              KV Oostende
# Brazil       NaN  NaN  NaN  NaN  NaN   827    244              Chapecoense
# Portugal     NaN  NaN  NaN  NaN  NaN   321    115       Vitória de Setúbal
# Spain        NaN  NaN  NaN  NaN  NaN  1072    159  Athletic Club de Bilbao
#
#                                                     Club Logo         \
#             freq mean  std  min  25%  50%  75%  max     count unique
# Nationality
# Argentina     27  NaN  NaN  NaN  NaN  NaN  NaN  NaN       937    183
# Belgium       14  NaN  NaN  NaN  NaN  NaN  NaN  NaN       260     94
# Brazil        20  NaN  NaN  NaN  NaN  NaN  NaN  NaN       827    244
# Portugal      17  NaN  NaN  NaN  NaN  NaN  NaN  NaN       322    116
# Spain         30  NaN  NaN  NaN  NaN  NaN  NaN  NaN      1072    159
#
#                                                                              \
#                                                          top freq mean  std
# Nationality
# Argentina    https://cdn.sofifa.org/teams/2/light/101083.png   27  NaN  NaN
# Belgium         https://cdn.sofifa.org/teams/2/light/682.png   14  NaN  NaN
# Brazil         https://cdn.sofifa.org/teams/2/light/1048.png   20  NaN  NaN
# Portugal        https://cdn.sofifa.org/teams/2/light/665.png   17  NaN  NaN
# Spain           https://cdn.sofifa.org/teams/2/light/448.png   30  NaN  NaN
#
#                                      Composure                             \
#              min  25%  50%  75%  max     count unique top freq       mean
# Nationality
# Argentina    NaN  NaN  NaN  NaN  Na
# Portugal     5.0  58.00  68.0  74.0  92.0      322.0    NaN NaN  NaN
# Spain        5.0  52.00  64.0  71.0  94.0     1071.0    NaN NaN  NaN
#
#                                                                Finishing  \
#                   mean        std  min   25%   50%   75%   max     count
# Nationality
# Argentina    44.883547  17.392798  8.0  34.0  43.0  58.0  94.0     936.0
# Belgium      47.104247  19.529960  8.0  33.0  48.0  64.5  83.0     259.0
# Brazil       50.255758  18.042864  7.0  39.0  51.0  65.0  87.0     825.0
# Portugal     48.670807  18.742151  9.0  35.0  49.0  66.0  83.0     322.0
# Spain        47.128852  17.899570  3.0  36.0  48.0  59.0  90.0    1071.0
#
#                                                                           \
#             unique top freq       mean        std  min   25%   50%   75%
# Nationality
# Argentina      NaN NaN  NaN  48.126068  19.947394  5.0  32.0  52.0  65.0
# Belgium        NaN NaN  NaN  46.482625  21.203579  2.0  28.0  52.0  64.0
# Brazil         NaN NaN  NaN  50.659394  19.450375  5.0  37.0  55.0  66.0
# Portugal       NaN NaN  NaN  48.891304  19.444881  5.0  34.0  53.5  65.0
# Spain          NaN NaN  NaN  48.765640  20.679535  5.0  32.0  54.0  66.0
#
#                    Flag                                                    \
#               max count unique                                  top  freq
# Nationality
# Argentina    95.0   937      1  https://cdn.sofifa.org/flags/52.png   937
# Belgium      87.0   260      1   https://cdn.sofifa.org/flags/7.png   260
# Brazil       88.0   827      1  https://cdn.sofifa.org/flags/54.png   827
# Portugal     94.0   322      1  https://cdn.sofifa.org/flags/38.png   322
# Spain        88.0  1072      1  https://cdn.sofifa.org/flags/45.png  1072
#
#                                                GKDiving                  \
#             mean  std  min  25%  50%  75%  max    count unique top freq
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN  NaN    936.0    NaN NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN  NaN    259.0    NaN NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN  NaN    825.0    NaN NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN  NaN    322.0    NaN NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN  NaN   1071.0    NaN NaN  NaN
#
#                                                               GKHandling  \
#                   mean        std  min  25%   50%   75%   max      count
# Nationality
# Argentina    16.309829  17.851441  4.0  8.0  11.0  14.0  83.0      936.0
# Belgium      19.459459  21.228210  5.0  8.0  11.0  14.0  85.0      259.0
# Brazil       15.846061  16.992983  1.0  8.0  11.0  14.0  85.0      825.0
# Portugal     16.736025  18.375671  4.0  9.0  11.0  14.0  86.0      322.0
# Spain        16.811391  18.496676  2.0  8.0  11.0  14.0  90.0     1071.0
#
#                                                                                \
#             unique top freq       mean        std  min  25%   50%   75%   max
# Nationality
# Argentina      NaN NaN  NaN  16.286325  17.074710  2.0  8.0  11.0  14.0  79.0
# Belgium        NaN NaN  NaN  19.069498  20.378659  5.0  8.0  11.0  15.0  91.0
# Brazil         NaN NaN  NaN  15.440000  16.188861  1.0  8.0  11.0  14.0  84.0
# Portugal       NaN NaN  NaN  16.670807  17.603199  4.0  9.0  12.0  15.0  81.0
# Spain          NaN NaN  NaN  16.835668  18.051667  2.0  8.5  11.0  14.0  85.0
#
#             GKKicking                                                         \
#                 count unique top freq       mean        std  min   25%   50%
# Nationality
# Argentina       936.0    NaN NaN  NaN  16.285256  17.000561  3.0  8.00  11.0
NaN  NaN  NaN  NaN  NaN  NaN  NaN  1071.0
#
#                                                                             \
#             unique top freq       mean        std   min   25%   50%    75%
# Nationality
# Argentina      NaN NaN  NaN  65.576923  12.657160  26.0  58.0  66.0  74.25
# Belgium        NaN NaN  NaN  66.227799  10.851635  33.0  59.5  67.0  74.00
# Brazil         NaN NaN  NaN  64.911515  12.071417  23.0  57.0  66.0  73.00
# Portugal       NaN NaN  NaN  65.990683  11.882206  30.0  59.0  67.0  74.00
# Spain          NaN NaN  NaN  64.953315  11.424669  29.0  59.0  66.0  73.00
#
#                     LAM                                                       \
#               max count unique   top freq mean  std  min  25%  50%  75%  max
# Nationality
# Argentina    94.0   839     66  68+2   39  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Belgium      91.0   219     51  64+2   15  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Brazil       93.0   757     66  69+2   47  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Portugal     95.0   290     53  68+2   17  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Spain        93.0   955     69  66+2   52  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                LB                                                        LCB  \
#             count unique   top freq mean  std  min  25%  50%  75%  max count
# Nationality
# Argentina     839     58  59+2   37  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839
# Belgium       219     49  68+2   11  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219
# Brazil        757     68  67+2   37  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757
# Portugal      290     52  67+2   16  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290
# Spain         955     70  59+2   46  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955
#
#                                                                    LCM         \
#             unique   top freq mean  std  min  25%  50%  75%  max count unique
# Nationality
# Argentina       64  67+2   40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     60
# Belgium         57  63+2   12  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     46
# Brazil          71  68+2   40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     62
# Portugal        61  69+2   17  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     45
# Spain           80  66+2   41  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     66
#
#                                                             LDM               \
#               top freq mean  std  min  25%  50%  75%  max count unique   top
# Nationality
# Argentina    64+2   47  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     62  57+2
# Belgium      57+2   14  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     50  66+2
# Brazil       61+2   47  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     70  68+2
# Portugal     61+2   21  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     56  65+2
# Spain        59+2   51  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     69  62+2
#
#                                                        LF                    \
#             freq mean  std  min  25%  50%  75%  max count unique   top freq
# Nationality
# Argentina     42  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     68  65+2   42
# Belgium       14  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     52  62+2   16
# Brazil        37  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     71  68+2   55
# Portugal      22  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     52  67+2   18
# Spain         46  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     67  63+2   52
#
#                                                   LM                         \
#             mean  std  min  25%  50%  75%  max count unique   top freq mean
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     64  67+2   47  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     52  63+2   18  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     69  68+2   44  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     54  69+2   19  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     67  60+2   51  NaN
#
#                                              LS                              \
#              std  min  25%  50%  75%  max count unique   top freq mean  std
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN   839     63  59+2   47  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN   219     47  64+2   13  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN   757     63  64+2   53  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN   290     46  68+2   15  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN   955     64  62+2   46  NaN  NaN
#
#                                         LW                                   \
#              min  25%  50%  75%  max count unique   top freq mean  std  min
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN   839     69  61+2   44  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN   219     53  65+2   17  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN   757     70  69+2   47  NaN  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN   290     53  68+2   19  NaN  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN   955     73  65+2   58  NaN  NaN  NaN
#
#                                   LWB                                        \
#              25%  50%  75%  max count unique   top freq mean  std  min  25%
# Nationality
# Argentina    NaN  NaN  NaN  NaN   839     57  56+2   49  NaN  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN   219     51  62+2   11  NaN  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN   757     63  60+2   36  NaN  NaN  NaN  NaN
# Portugal     NaN  NaN  NaN  Na
# Brazil       NaN  NaN  NaN   827.0    NaN NaN  NaN  71.251511  5.590515  48.0
# Portugal     NaN  NaN  NaN   322.0    NaN NaN  NaN  71.344720  5.469467  57.0
# Spain        NaN  NaN  NaN  1072.0    NaN NaN  NaN  69.698694  6.494103  51.0
#
#                                     Penalties                             \
#               25%   50%   75%   max     count unique top freq       mean
# Nationality
# Argentina    64.0  69.0  73.0  94.0     936.0    NaN NaN  NaN  51.841880
# Belgium      64.0  68.0  72.0  91.0     259.0    NaN NaN  NaN  49.980695
# Brazil       68.0  71.0  74.0  92.0     825.0    NaN NaN  NaN  55.300606
# Portugal     68.0  71.0  74.0  94.0     322.0    NaN NaN  NaN  53.475155
# Spain        65.0  69.0  74.0  91.0    1071.0    NaN NaN  NaN  51.014939
#
#                                                      Photo         \
#                    std   min   25%   50%   75%   max count unique
# Nationality
# Argentina    15.403472  10.0  43.0  53.0  63.0  90.0   937    937
# Belgium      16.460300  10.0  38.0  52.0  62.0  86.0   260    260
# Brazil       15.531422  11.0  47.0  59.0  67.0  91.0   827    827
# Portugal     16.385951  11.0  44.0  55.0  66.0  89.0   322    322
# Spain        16.076213  10.0  41.0  51.0  63.0  88.0  1072   1072
#
#                                                                             \
#                                                         top freq mean  std
# Nationality
# Argentina    https://cdn.sofifa.org/players/4/19/226757.png    1  NaN  NaN
# Belgium      https://cdn.sofifa.org/players/4/19/245459.png    1  NaN  NaN
# Brazil       https://cdn.sofifa.org/players/4/19/203239.png    1  NaN  NaN
# Portugal     https://cdn.sofifa.org/players/4/19/194979.png    1  NaN  NaN
# Spain        https://cdn.sofifa.org/players/4/19/235754.png    1  NaN  NaN
#
#                                      Position                                 \
#              min  25%  50%  75%  max    count unique top freq mean  std  min
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN      936     25  ST  125  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN      259     22  GK   40  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN      825     24  ST  111  NaN  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN      322     21  LB   34  NaN  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN     1071     25  GK  116  NaN  NaN  NaN
#
#                                 Positioning                             \
#              25%  50%  75%  max       count unique top freq       mean
# Nationality
# Argentina    NaN  NaN  NaN  NaN       936.0    NaN NaN  NaN  52.368590
# Belgium      NaN  NaN  NaN  NaN       259.0    NaN NaN  NaN  51.003861
# Brazil       NaN  NaN  NaN  NaN       825.0    NaN NaN  NaN  54.738182
# Portugal     NaN  NaN  NaN  NaN       322.0    NaN NaN  NaN  55.366460
# Spain        NaN  NaN  NaN  NaN      1071.0    NaN NaN  NaN  53.631186
#
#                                                     Potential                  \
#                    std  min   25%   50%   75%   max     count unique top freq
# Nationality
# Argentina    19.959795  4.0  41.0  58.0  67.0  94.0     937.0    NaN NaN  NaN
# Belgium      21.735995  4.0  37.5  57.0  67.0  89.0     260.0    NaN NaN  NaN
# Brazil       20.089830  3.0  42.0  61.0  70.0  89.0     827.0    NaN NaN  NaN
# Portugal     20.340923  6.0  45.0  63.0  70.0  95.0     322.0    NaN NaN  NaN
# Spain        20.035373  4.0  44.0  59.0  68.0  89.0    1072.0    NaN NaN  NaN
#
#                                                                Preferred Foot  \
#                   mean       std   min   25%   50%   75%   max          count
# Nationality
# Argentina    73.210245  5.309601  57.0  69.0  73.0  77.0  94.0            936
# Belgium      74.388462  5.755563  62.0  70.0  74.0  78.0  92.0            259
# Brazil       73.351874  5.785576  59.0  69.0  73.0  77.0  93.0            825
# Portugal     75.298137  5.696744  62.0  71.0  75.0  79.0  94.0            322
# Spain        74.616604  5.604905  57.0  71.0  74.0  78.0  93.0           1071
#
#                                                                     RAM  \
#             unique    top freq mean  std  min  25%  50%  75%  max count
# Nationality
# Argentina        2  Right  722  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839
# Belgium          2  Right  201  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219
# Brazil           2  Right  580  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757
# Portugal         2  Right  249  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290
# Spain            2  Right  773  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955
#
#                                                                     RB         \
#             unique   top freq mean  std  min  25%  50%  75%  max count unique
# Nationality
# Argentina       66  68+2   39  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     58
# Belgium         51  64+2   15  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     49
# Brazil          66  69+2   47  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     68
# Portugal        53  68+2   17  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     52
# Spain           69  66+2   52  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     70
#
#                                                             RCB               \
#               top freq mean  std  min  25%  50%  75%  max count unique   top
# Nationality
# Argentina    59+2   37  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     64  67+2
# Belgium      68+2   11  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     57  63+2
# Brazil       67+2   37  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     71  68+2
# Portugal     67+2   16  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     61  69+2
# Spain        59+2   46  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     80  66+2
#
#                                                       RCM                    \
#             freq mean  std  min  25%  50%  75%  max count unique   top freq
# Nationality
# Argentina     40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     60  64+2   47
# Belgium       12  NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     46  57+2   14
# Brazil        40  NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     62  61+2   47
# Portugal      17  NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     45  61+2   21
# Spain         41  NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     66  59+2   51
#
#                                                  RDM                         \
#             mean  std  min  25%  50%  75%  max count unique   top freq mean
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN  NaN   839     62  57+2   42  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN  NaN   219     50  66+2   14  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN  NaN   757     70  68+2   37  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN  NaN   290     56  65+2   22  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN  NaN   955     69  62+2   46  NaN
#
#                                              RF                              \
#              std  min  25%  50%  75%  max count unique   top freq mean  std
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN  NaN   839     68  65+2   42  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN  NaN   219     52  62+2   16  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN  NaN   757     71  68+2   55  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN  NaN   290     52  67+2   18  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN  NaN   955     67  63+2   52  NaN  NaN
#
#                                         RM                                   \
#              min  25%  50%  75%  max count unique   top freq mean  std  min
# Nationality
# Argentina    NaN  NaN  NaN  NaN  NaN   839     64  67+2   47  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN  NaN   219     52  63+2   18  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN  NaN   757     69  68+2   44  NaN  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN  NaN   290     54  69+2   19  NaN  NaN  NaN
# Spain        NaN  NaN  NaN  NaN  NaN   955     67  60+2   51  NaN  NaN  NaN
#
#                                    RS                                        \
#              25%  50%  75%  max count unique   top freq mean  std  min  25%
# Nationality
# Argentina    NaN  NaN  NaN  NaN   839     63  59+2   47  NaN  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN  NaN   219     47  64+2   13  NaN  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN  NaN   757     63  64+2   53  NaN  NaN  NaN  NaN
# Portugal     NaN  NaN  NaN  NaN   290     46  68+2   15  NaN  NaN  NaN  NaN
# Spain        NaN  NaN  NaN  NaN   955     64  62+2   46  NaN  NaN  NaN  NaN
#
#                               RW                                             \
#              50%  75%  max count unique   top freq mean  std  min  25%  50%
# Nationality
# Argentina    NaN  NaN  NaN   839     69  61+2   44  NaN  NaN  NaN  NaN  NaN
# Belgium      NaN  NaN  NaN   219     53  65+2   17  NaN  NaN  NaN  NaN  NaN
# Brazil       NaN  NaN  NaN   757     70  69+2   47  NaN  NaN  NaN  NaN  NaN
# Portugal     NaN  NaN  Na
NaN  NaN  NaN  NaN  NaN  NaN  NaN  1071.0    NaN NaN
#
#                                                                      Volleys  \
#             freq       mean        std   min   25%   50%   75%   max   count
# Nationality
# Argentina    NaN  54.862179  15.170307  13.0  45.0  57.0  67.0  94.0   936.0
# Belgium      NaN  56.575290  14.134361  18.0  47.0  58.0  67.0  94.0   259.0
# Brazil       NaN  58.113939  14.087939  11.0  49.0  60.0  69.0  90.0   825.0
# Portugal     NaN  59.195652  13.668605  22.0  50.0  61.0  69.0  86.0   322.0
# Spain        NaN  57.084967  14.425486  11.0  46.5  59.0  68.0  93.0  1071.0
#
#                                                                            \
#             unique top freq       mean        std  min   25%   50%    75%
# Nationality
# Argentina      NaN NaN  NaN  44.863248  17.835808  5.0  32.0  46.0  58.25
# Belgium        NaN NaN  NaN  46.405405  20.319963  5.0  28.0  52.0  63.00
# Brazil         NaN NaN  NaN  49.918788  17.986158  6.0  39.0  53.0  63.00
# Portugal       NaN NaN  NaN  48.909938  18.563387  5.0  35.0  51.0  64.00
# Spain          NaN NaN  NaN  44.512605  17.937159  5.0  32.0  46.0  58.00
#
#                    Wage                                                      \
#               max count unique  top freq mean  std  min  25%  50%  75%  max
# Nationality
# Argentina    90.0   937     70  €2K  143  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Belgium      85.0   260     52  €2K   42  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Brazil       85.0   827     79  €4K   61  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Portugal     87.0   322     58  €3K   33  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Spain        90.0  1072     94  €2K  133  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#             Weak Foot                                                          \
#                 count unique top freq      mean       std  min  25%  50%  75%
# Nationality
# Argentina       936.0    NaN NaN  NaN  2.870726  0.598892  1.0  3.0  3.0  3.0
# Belgium         259.0    NaN NaN  NaN  3.204633  0.747488  1.0  3.0  3.0  4.0
# Brazil          825.0    NaN NaN  NaN  2.945455  0.749227  1.0  2.0  3.0  3.0
# Portugal        322.0    NaN NaN  NaN  3.046584  0.661117  2.0  3.0  3.0  3.0
# Spain          1071.0    NaN NaN  NaN  3.004669  0.537367  2.0  3.0  3.0  3.0
#
#                  Weight                                                    \
#              max  count unique     top freq mean  std  min  25%  50%  75%
# Nationality
# Argentina    5.0    936     42  154lbs   64  NaN  NaN  NaN  NaN  NaN  NaN
# Belgium      5.0    259     37  176lbs   17  NaN  NaN  NaN  NaN  NaN  NaN
# Brazil       5.0    825     38  165lbs   65  NaN  NaN  NaN  NaN  NaN  NaN
# Portugal     5.0    322     33  154lbs   24  NaN  NaN  NaN  NaN  NaN  NaN
# Spain        5.0   1071     38  165lbs   98  NaN  NaN  NaN  NaN  NaN  NaN
#
#                  Work Rate                                                  \
#              max     count unique             top freq mean  std  min  25%
# Nationality
# Argentina    NaN       936      8  Medium/ Medium  465  NaN  NaN  NaN  NaN
# Belgium      NaN       259      8  Medium/ Medium  141  NaN  NaN  NaN  NaN
# Brazil       NaN       825      8  Medium/ Medium  441  NaN  NaN  NaN  NaN
# Portugal     NaN       322      9  Medium/ Medium  160  NaN  NaN  NaN  NaN
# Spain        NaN      1071      8  Medium/ Medium  634  NaN  NaN  NaN  NaN
#
#
#              50%  75%  max
# Nationality
# Argentina    NaN  NaN  NaN
# Belgium      NaN  NaN  NaN
# Brazil       NaN  NaN  NaN
# Portugal     NaN  NaN  NaN
# Spain        NaN  NaN  NaN

# %%
#print(df.groupby(['Nationality'])['Overall'].mean().nlargest(5))

#print(df.groupby(['Nationality'])['Overall'].median().nlargest(5))

#print(df.groupby(['Nationality'])['Overall'].count().nlargest(5))

# %%
import seaborn as sns
plt.figure()
sns.distplot(df[df['Nationality']=='Brazil']['Overall'], color='g', bins=10);
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/andremota/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_2[df_2['Nationality']=='Brazil'].hist(figsize=(10, 8), bins=10, xlabelsize=2, ylabelsize=6);
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Boxplot para comparar Brazil e Argentina
plt.figure(figsize=(4,4))

plt.boxplot([df[df['Nationality'] == 'Brazil']['Overall'], df[df['Nationality'] == 'Argentina']['Overall']])

plt.suptitle('Overall: Brasil x Argentina', fontsize=14)

plt.xticks([1, 2], ['Brazil', 'Argentina'])

#pinta os quadrados
#plt.boxplot([df[df['Nationality'] == 'Brazil']['Overall'], df[df['Nationality'] == 'Argentina']['Overall']],patch_artist=True)

#esconder bordas
#ax = plt.subplot(111)
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)

#exemplo de como selecionar varios filtros
#array = ['Brazil', 'Argentina']
#plt.boxplot(df[df['Nationality'].isin(array)]['Overall'])

#Como colorir outliers
#outlier_color_format = dict(markerfacecolor='r', marker='D')
#plt.boxplot([df[df['Nationality'] == 'Brazil']['Overall'], df[df['Nationality'] == 'Argentina']['Overall']],flierprops=outlier_color_format)

#como esconder outliers
#plt.boxplot([df[df['Nationality'] == 'Brazil']['Overall'], df[df['Nationality'] == 'Argentina']['Overall']], showfliers=False)
# Out:
# <img src="data:image/png;base64,..." width="400">
# ([<matplotlib.axis.XTick at 0x1a225baf28>,
#   <matplotlib.axis.XTick at 0x1a225ba828>],
#  <a list of 2 Text xticklabel objects>)

# %%
plt.figure()
plt.hist(df[df['Nationality'] == 'Brazil']['Overall'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  1.,   5.,  12.,  91., 205., 310., 124.,  59.,  15.,   5.]),
#  array([48. , 52.4, 56.8, 61.2, 65.6, 70. , 74.4, 78.8, 83.2, 87.6, 92. ]),
#  <a list of 10 Patch objects>)

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns

# %%
import pandas as pd
df = pd.DataFrame({'Club': ['Palmeiras', 'SPFC', 'Corinthians', 'Palmeiras', 'SPFC'], 
               'Player': ['FFFFF', 'EEEE', 'DDDD', 'CCCC', 'BBBB'],
              'Balance':[70,80,90,50,60],
                   'Speed':[90,89, 70, 88, 80],
                   'Aggression':[70, 74, 80, 85, 66]
                })

print("Club with highest speed: "+ df.groupby('Club')['Speed'].mean().reset_index().sort_values('Speed',ascending=False).iloc[0,0])
# Out:
# Club
# Corinthians    70.0
# Palmeiras      89.0
# SPFC           84.5
# Name: Speed, dtype: float64

# %% [markdown]
# ## DATA SCIENCE TUTORIAL (KERNEL KAGGLE)
#
# https://www.kaggle.com/aliylmaz0907/data-sciencetutorial-for-beginners

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
#print(os.listdir("../input"))

# %%
data=pd.read_csv('fifa19.csv')

# %%
data.info() # this code give us general information about our data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# Body Type                   18159 non-null object
# Real Face                   18159 non-null object
# Position                    18147 non-null object
# Jersey Number               18147 non-null float64
# Joined                      16654 non-null object
# Loaned From                 1264 non-null object
# Contract Valid Until        17918 non-null object
# Height                      18159 non-null object
# Weight                      18159 non-null object
# LS                          16122 non-null object
# ST                          16122 non-null object
# RS                          16122 non-null object
# LW                          16122 non-null object
# LF                          16122 non-null object
# CF                          16122 non-null object
# RF                          16122 non-null object
# RW                          16122 non-null object
# LAM                         16122 non-null object
# CAM                         16122 non-null object
# RAM                         16122 non-null object
# LM                          16122 non-null object
# LCM                         16122 non-null object
# CM                          16122 non-null object
# RCM                         16122 non-null object
# RM                          16122 non-null object
# LWB                         16122 non-null object
# LDM                         16122 non-null object
# CDM                         16122 non-null object
# RDM                         16122 non-null object
# RWB                         16122 non-null object
# LB                          16122 non-null object
# LCB                         16122 non-null object
# CB                          16122 non-null object
# RCB                         16122 non-null object
# RB                          16122 non-null object
# Crossing                    18159 non-null float64
# Finishing                   18159 non-null float64
# HeadingAccuracy             18159 non-null float64
# ShortPassing                18159 non-null float64
# Volleys                     18159 non-null float64
# Dribbling                   18159 non-null float64
# Curve                       18159 non-null float64
# FKAccuracy                  18159 non-null float64
# LongPassing                 18159 non-null float64
# BallControl                 18159 non-null float64
# Acceleration                18159 non-null float64
# SprintSpeed                 18159 non-null float64
# Agility                     18159 non-null float64
# Reactions                   18159 non-null float64
# Balance                     18159 non-null float64
# ShotPower                   18159 non-null float64
# Jumping                     18159 non-null float64
# Stamina                     18159 non-null float64
# Strength                    18159 non-null float64
# LongShots                   18159 non-null float64
# Aggression                  18159 non-null float64
# Interceptions               18159 non-null float64
# Positioning                 18159 non-null float64
# Vision                      18159 non-null float64
# Penalties                   18159 non-null float64
# Composure                   18159 non-null float64
# Marking                     18159 non-null float64
# StandingTackle              18159 non-null float64
# SlidingTackle               18159 non-null float64
# GKDiving                    18159 non-null float64
# GKHandling                  18159 non-null float64
# GKKicking                   18159 non-null float64
# GKPositioning               18159 non-null float64
# GKReflexes                  18159 non-null float64
# Release Clause              16643 non-null object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
data.describe() #this code give us  digital information. After we will look closely.
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# std      272.586016                  0.394031      0.660456      0.756164
# min      731.000000                  1.000000      1.000000      1.000000
# 25%     1457.000000                  1.000000      3.000000      2.000000
# 50%     1635.000000                  1.000000      3.000000      2.000000
# 75%     1787.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number      ...          Penalties     Composure       Marking  \
# count   18147.000000      ...       18159.000000  18159.000000  18159.000000
# mean       19.546096      ...          48.548598     58.648274     47.281623
# std        15.947765      ...          15.704053     11.436133     19.904397
# min         1.000000      ...           5.000000      3.000000      3.000000
# 25%         8.000000      ...          39.000000     51.000000     30.000000
# 50%        17.000000      ...          49.000000     60.000000     53.000000
# 75%        26.000000      ...          60.000000     67.000000     64.000000
# max        99.000000      ...          92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 44 columns]

# %%
# Line plot is better when x axis is time. Let's make one

# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.Finishing.plot(kind = 'line', color = 'g',label = 'Finishing',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Positioning.plot(color = 'r',label = 'Positioning',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
# Scatter is better when there is correlation between two variables

# x = Special, y = Skill Moves
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.plot(kind='scatter', x='Special', y='Skill Moves',alpha = 0.5,color = 'red')
plt.xlabel('Special')              # label = name of label
plt.ylabel('Skill Moves')
plt.title('Special Skill Moves Scatter Plot')  # title = title of plot
plt.show()          # for showing plot

# %%
# Histogram is better when we need to see distribution of numerical data.
# bins = number of bar in figure
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.SprintSpeed.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
# clf() = cleans it up again you can start a fresh
data.SprintSpeed.plot(kind = 'hist',bins = 50)
plt.clf()
# We cannot see plot due to clf()

# %% [markdown]
# ## DICTIONARY
#
# Why we need dictionary?
#
#     It has 'key' and 'value' ,each key has a value(s)
#     Faster than lists
#     What is key and value. Example:
#     dictionary = {'spain' : 'madrid'}
#     Key is spain.
#     Values is madrid.
#
#     It's that easy.
#     Lets practice some other properties like keys(), values(), update, add, check, remove key, remove all entries and remove dicrionary.

# %%
#create dictionary and look its keys and values
dictionary = {'istanbul' : 'besiktas','paris' : 'psg'}
print("dictionary:",dictionary)
print(dictionary.keys())
print(dictionary.values())
# Out:
# dictionary: {'istanbul': 'besiktas', 'paris': 'psg'}
# dict_keys(['istanbul', 'paris'])
# dict_values(['besiktas', 'psg'])

# %%
# Keys have to be immutable objects like string, boolean, float, integer or tubles
# List is not immutable
# Keys are unique
dictionary['istanbul'] = "galatasaray"    # update existing entry
print(dictionary)
dictionary['madrid'] = "realmadrid"       # Add new entry
print(dictionary)
# Out:
# {'istanbul': 'galatasaray', 'paris': 'psg'}
# {'istanbul': 'galatasaray', 'paris': 'psg', 'madrid': 'realmadrid'}

# %%
del dictionary['istanbul']              # remove entry with key 'spain'
print(dictionary)
print('paris' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'paris': 'psg', 'madrid': 'realmadrid'}
# True
# {}

# %%
# In order to run all code you need to take comment this line
# del dictionary         # delete entire dictionary     
print(dictionary)       # it gives error because dictionary is deleted
# Out:
# {}
